# %% [markdown]
# Índices y slicing

# %%
codigo = "V-2024-1001"
sufijo = "_BANK"

# %% [markdown]
# CONCATENAR

# %%
codigo + "_" + sufijo
# Out:
# 'V-2024-1001__BANK'

# %%
codigo = "V-2024-1001"

codigo[3]
# Out:
# '0'

# %%
codigo[-1]
# Out:
# '1'

# %%
codigo[1:4]
# Out:
# '-20'

# %%
codigo[:3]
# Out:
# 'V-2'

# %% [markdown]
# INVERTIR

# %%
codigo[::-1]
# Out:
# '1001-4202-V'

# %% [markdown]
# METODOS Y TRATAMIENTOS DE LIMPIEZA

# %%
nombre = "AnA            Torres          "
apellido_materno = "Zeballos"
##CONTAR NUMERO DE CARACTERES
print(f"numero de caracteres: {len(nombre)}")
print(f"numero de caracteres: {len(apellido_materno)}")
# Out:
# numero de caracteres: 31
# numero de caracteres: 8

# %%
#ELIMINA ESPACIOS
print(len(nombre.strip()))
# Out:
# 21

# %%
#CONVERTIR A MINISCULA Y MAYUSCULA
print(nombre.lower())
print(nombre.upper())
print(nombre.title())
# Out:
# ana            torres
# ANA            TORRES
# Ana            Torres

# %%
nombre.replace("Torres", "LLERENA")
# Out:
# 'AnA            LLERENA          '

# %%
nombre.replace(" ", "").replace("AT", "A T").title()
# Out:
# 'Ana Torres'

# %%
nombre.split()
# Out:
# ['AnA', 'Torres']

# %%
" ".join(nombre.split())
# Out:
# 'AnA Torres'

# %%
" ".join(nombre.split()).title()
# Out:
# 'Ana Torres'

# %%
nombre = "AnaxxTorres"
nombre.split("xx")
", ".join(nombre.split("xx"))
# Out:
# 'Ana, Torres'

# %% [markdown]
# SI EMPIEZA CON VARIABLE ES VERDADERO O FALSO

# %%
codigo = "V-2024-1001"

codigo.startswith("V")
# Out:
# True

# %%
codigo.startswith("F")
# Out:
# False

# %%
codigo.endswith("6")
# Out:
# False

# %% [markdown]
# REGEX

# %%
import re

nombre = "AnA            Torres          "
nombre_limpio = re.sub(r"\s+", " ", nombre).strip().title()
print(f"'{nombre_limpio}'")
# Out:
# 'Ana Torres'

# %% [markdown]
# VALIDAR Y BUSCAR TEXTO

# %%
Ciudad = "Arequipa"
texto = "Region: Paucarpata, Cerro colorado, Yanahuara, Tiabaya, "

# %%
"Yanahuara" in texto
# Out:
# True

# %%
"Socabaya" in texto
# Out:
# False

# %%
"Socabaya" not in texto
# Out:
# True

# %%
codigo = "V-2024-1001"
##REGRESA LA POSISICON DONDE SE ENCUENTRA
codigo.find("V")
# Out:
# 0

# %%
codigo.find("-")
# Out:
# 1

# %%
codigo.count("-")
# Out:
# 2

# %%
"1001".isdigit()
# Out:
# True

# %%
"10.5".isdigit()
# Out:
# False

# %%
"Ana".isalpha()
# Out:
# True

# %%
"Ana".isupper()
# Out:
# False

# %%
"ANA".isupper()
# Out:
# True

# %% [markdown]
# Forma Antigua

# %%
mi_nombre = "Joel"

print("Me llamo: ", mi_nombre)
# Out:
# Me llamo:  Joel

# %% [markdown]
# Forma Moderna

# %%
print(f"Me llamo: {mi_nombre}")
# Out:
# Me llamo: Joel

# %%
cliente = "Ana Torres"
total = 6000.5

print("Cliente:", cliente, "|" ,"Total:", total)
print(f"Cliente: {cliente} |  Total: {total}")
#redondea
print(f"Cliente: {cliente} |  Total: {total*2}")
print(f"Cliente: {cliente} |  Total: {total*2:.2f}")
# Out:
# Cliente: Ana Torres | Total: 6000.5
# Cliente: Ana Torres |  Total: 6000.5
# Cliente: Ana Torres |  Total: 12001.0
# Cliente: Ana Torres |  Total: 12001.00

# %%
numero_1 = 20
numero_2 = 10

# %%
numero_1 + numero_2
# Out:
# 30

# %%
numero_2 - numero_1
# Out:
# -10

# %%
numero_1 / numero_2
# Out:
# 2.0

# %%
numero_1 // numero_2
# Out:
# 2

# %%
numero_2 % numero_1
# Out:
# 10
